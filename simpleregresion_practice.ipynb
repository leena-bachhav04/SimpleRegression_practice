# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
plt.scatter(df["cgpa"],df["iq"])
plt.xlabel("cgpa")
plt.ylabel("iq")
# Out:
# Text(0, 0.5, 'iq')

# %%
x=df.iloc[:,0:1]

# %%
y=df.iloc[:,-1]

# %%
x
# Out:
#     Unnamed: 0
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
# ..         ...
# 95          95
# 96          96
# 97          97
# 98          98
# 99          99
#
# [100 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test
# Out:
#     Unnamed: 0
# 83          83
# 30          30
# 56          56
# 24          24
# 16          16
# 23          23
# 2            2
# 27          27
# 28          28
# 13          13
# 99          99
# 92          92
# 76          76
# 14          14
# 0            0
# 21          21
# 3            3
# 29          29
# 61          61
# 79          79

# %%
y_test
# Out:
# 83    1
# 30    1
# 56    0
# 24    0
# 16    0
# 23    0
# 2     0
# 27    1
# 28    0
# 13    1
# 99    1
# 92    0
# 76    0
# 14    0
# 0     1
# 21    1
# 3     1
# 29    1
# 61    1
# 79    1
# Name: placement, dtype: int64

# %%
lr.predict(x_test.iloc[1].values.reshape(1,1))
# Out:
# C:\Users\Leena Bachhav\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([0.41341042])

# %%
m=lr.coef_

# %%
b=lr.intercept_

# %%
m*30+b
# Out:
# array([0.41341042])
